# %% [markdown]
# <a href="https://colab.research.google.com/github/johnlaraji1608-collab/heightvsweight_linearregression/blob/main/heightvsweight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('/content/data.csv')

# %%
df.head()
# Out:
#    Height  Weight
# 0    1.47   52.21
# 1    1.50   53.12
# 2    1.52   54.48
# 3    1.55   55.84
# 4    1.57   57.20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Height  15 non-null     float64
#  1   Weight  15 non-null     float64
# dtypes: float64(2)
# memory usage: 372.0 bytes

# %%
df.describe()
# Out:
#           Height     Weight
# count  15.000000  15.000000
# mean    1.650667  62.078000
# std     0.114235   7.037515
# min     1.470000  52.210000
# 25%     1.560000  56.520000
# 50%     1.650000  61.290000
# 75%     1.740000  67.190000
# max     1.830000  74.460000

# %%
y = df['Weight']
x = df['Height']
z = sm.add_constant(x)
result = sm.OLS(y, x).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared (uncentered):                   0.998
# Model:                            OLS   Adj. R-squared (uncentered):              0.998
# Method:                 Least Squares   F-statistic:                              7476.
# Date:                Fri, 06 Mar 2026   Prob (F-statistic):                    1.67e-20
# Time:                        14:34:29   Log-Likelihood:                         -36.182
# No. Observations:                  15   AIC:                                      74.36
# Df Residuals:                      14   BIC:                                      75.07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
plt.scatter(y, x)
plt.xlabel('Weight', fontsize=15)
plt.ylabel('Age', fontsize=15)
plt.show()

# %%
plt.scatter(x, y)
yhat = 	-39.0620 + 61.2722 * x
fig = plt.plot(x, yhat, lw=2, c='orange', label='Regression Line')
plt.xlabel('Weight', fontsize=15)
plt.ylabel('Age', fontsize=15)
plt.show()
